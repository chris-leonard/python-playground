# %% [markdown]
# # Stochastic Processes
#
# Notes on stochastic processes from a probabilistic perspective.

# %% [markdown]
# ## Measure Theory
#
# **Definition:** A *$\sigma$-algebra* $\mathcal{F}$ on a set $\Omega$ is a non-empty subset of the powerset $\mathcal{P}(\Omega)$ of $\Omega$ that is closed under complements, countable unions, and countable intersections. The pair $\left(\Omega, \mathcal{F}\right)$ is called a *measureable space* and the elements of $\mathcal{F}$ are called *measurable sets*.
#
# **Examples:**
# 1. If $\Omega$ is any non-empty set then $\lbrace \emptyset, \Omega\rbrace$ is a $\sigma$-algebra on $\Omega$.
# 2. If $\Omega$ is any non-empty set then $\mathcal{P}\left(\Omega\right)$ is a $\sigma$-algebra on $\Omega$.
# 3. If $\Omega=\lbrace a, b, c, d\rbrace$ then $\lbrace \emptyset, \lbrace a, b\rbrace, \lbrace c, d\rbrace, \Omega\rbrace$ is a $\sigma$-algebra on $\Omega$.
#
# **Definition:** If $\mathcal{F}$ is any subset of $\mathcal{P}(\Omega)$ then there is a unique smallest $\sigma$-algebra $\sigma\left(\mathcal{F}\right)$ on $\Omega$ containing $\mathcal{F}$; the intersection of all $\sigma$-algebras on $\Omega$ containing $\mathcal{F}$. This is called the *$\sigma$-algebra generated by $\mathcal{F}$*.
#
# **Example:** Suppose that $\Omega$ is a topological space. The *Borel $\sigma$-algebra* $\mathcal{B}\left(\Omega\right)$ on $\Omega$ is the $\sigma$-algebra generated by all open (or all closed) sets in $\Omega$. The elements of $\mathcal{B}$ are called *Borel sets*. If $\Omega=\mathbb{R}$ with the usual topology then $\mathcal{B}\left(\mathbb{R}\right)$ is generated by any out of:
# - all open intervals $(a, b)$, $a\in\mathbb{R}$;
# - all half-open intervals $(a, b]$, $a, b\in\mathbb{R}$;
# - all intervals $(a, \infty)$, $a\in\mathbb{R}$;
# - all intervals $(-\infty, b]$, $b\in\mathbb{R}$.
#
# **Definition:** Suppose that $\Omega$ and $S$ are non-empty sets, $\Sigma$ is a $\sigma$-algebra on $S$, and $f:\Omega\to S$ is a function. Let $\sigma(f)$ denote the set of pre-images of elements of $\Sigma$:
#
# \begin{equation}
#     \sigma(f) = \lbrace\, f^{-1}(E) \,\mid\, E\in\Sigma \,\rbrace.
# \end{equation}
#
# Then $\sigma(f)$ is a $\sigma$-algebra on $\Omega$ called the *$\sigma$-algebra generated by $f$*.
#
#
# **Definition:** Suppose that $\left(\Omega, \mathcal{F}\right)$ and $\left(S, \Sigma\right)$ are measurable spaces and $f:\Omega\to S$. We call $f$ a *measurable function*, or more precisely a *$\left(\mathcal{F}, \Sigma\right)$-measurable function*, if $\sigma(f)\subseteq \mathcal{F}$. That is, if
# $f^{-1}(E)\in\mathcal{F}$ for all $E\in\Sigma$.

# %% [markdown]
# ## Probability
#
# ### Probability Spaces
#
# **Definition:** A *probability space* is a triple $\left(\Omega, \mathcal{F}, P\right)$ where:
# - $\Omega$ is a non-empty set called the *sample space*;
# - $\mathcal{F}$ is a $\sigma$-algebra on $\Omega$ called the *event space*, whose elements are *events*;
# - $P$ is a *probability measure* on $\left(\Omega, \mathcal{F}\right)$; a function $\mathcal{F}\to[0, 1]$ such that:
#     - $P(\Omega)=1$;
#     - $P$ is *$\sigma$-additive*: if $E_n\in\mathcal{F}$ ($n\in\mathbb{N}$) is a countable collection of pair-wise disjoint events then
#
# \begin{equation}
#     P\left( \bigcup_{n\in\mathbb{N}} E_i\right) = \sum_{n\in\mathbb{N}} P\left(E_n\right).
# \end{equation}
#
# **Example:** Consider a coin flip where the coin has a probability $p\in[0, 1]$ of coming up heads. This can be represented by the probability space $\left(\Omega, \mathcal{F}, P\right)$ with $\Omega=\lbrace H, T\rbrace$, $\mathcal{F}=\mathcal{P}\left( \mathcal{\Omega}\right)=\lbrace \emptyset, \lbrace H\rbrace, \lbrace T\rbrace, \lbrace H, T\rbrace\rbrace$, and $P$ the unique probability measure with $P(H)=p$ and $P(T)=1-p$.
#
# We should think of $\Omega$ as the outcomes that can happen and $\mathcal{F}$ as the information that's available, or what outcomes can be distinguished from each other. Often $\mathcal{F}=\Omega$, but it can be useful to consider smaller $\sigma$-algebras that represent the outcomes that can be determined with partial information.
#
# **Example:** Consider two sequential flips of a coin, each having probability $p$ of coming up heads. This situation is described by the probability space with $\Omega=\lbrace HH, HT, TH, TT\rbrace$, $\mathcal{F}=\mathcal{P}\left(\Omega\right)$, and $P$ the unique probability measure determined by
#
# \begin{equation}
#     P(HH)=p^2, \qquad P(HT)=P(TH)=1-p, \qquad P(TT)=(1-p)^2.
# \end{equation}
#
# But suppose we wish to describe the observed information after the first flip. The outcomes $HH$ and $HT$ can't be distinguished with this limited information, so shouldn't be considered distinct events. Instead, define a new event space $\mathcal{F}_1 = \lbrace \emptyset, \lbrace HH, HT\rbrace, \lbrace TH, TT\rbrace, \Omega \rbrace$. The probability space $\left(\Omega, \mathcal{F}_1, P\big|_{\mathcal{F}_1}\right)$ represents this information that can be determined at this point.

# %% [markdown]
# ### Random Variables
#
# **Definition:** Let $\left(\Omega, \mathcal{F}, P\right)$ be a probability space and $\left( S, \Sigma\right)$ be a measurable space. A *random variable*, or more precisely a *$\left( S, \Sigma\right)$-valued random variable* is a $\left(\mathcal{F}, \Sigma\right)$-measurable function $X:\Omega\to S$.
#
# **Notation:** If $A\in\Sigma$ is a measureable set then we define
#
# \begin{equation}
#     P\left( X\in A\right) \mathrel{\mathop:}= P\left( X^{-1}(A)\right).
# \end{equation}
#
# If $A=\{a\}$ then we will write $P\left(X=a\right)$ in place of $P\left( X\in A\right)$. Finally, if $S\subseteq\mathbb{R}$ and $A=(-\infty, b]$ (or its intersection with $S$) we write $P\left( X\leq b\right)$ in place of $P\left( X\in A\right)$. This extends to other inequalities in the obvious way.
#
# **Examples:**
# 1. Let $S$ be a countable set and $\Sigma=\mathcal{P}(S)$, or equivalently let $\Sigma$ be the Borel $\sigma$-algebra $\mathcal{B}(S)$ of $S$ where $S$ is endowed with the discrete topology (all sets are both open and closed). Since $\Sigma$ is generated (as a $\sigma$-algebra) by all singletons, a function $X:\Omega\to S$ is a random variable if and only if $P\left(X=a\right)$ is well-defined for all $a\in S$. If so, we call $X$ a *discrete random variable*. Particularly important examples are $S=\mathbb{N}$ and $S=\mathbb{Z}$.
# 2. Let $S=\mathbb{R}$ with its usual topology and set $\Sigma=\mathcal{B}\left(\mathbb{R}\right)$. A function $X:\Omega\to \mathbb{R}$ is a random variable if and only $P(X\leq b)$ is well-defined for all $b\in\mathbb{R}$ (or $P(a<X<b)$ is well-defined for all $a, b\in\mathbb{R}$, etc.). If so, we call $X$ a *real-valued random variable*, or simply a *real random variable*.
#
# Note that since singletons are closed in $\mathcal{B}\left(\mathbb{R}\right)$, if $S$ is a countable subset of $\mathbb{R}$ then the two examples coincide. In this case we might call $X$ a *discrete real-valued random variable*.
#
# **Convention:** With real random variables the sample and event spaces are almost incidental and we often describe real-valued random variables solely in terms of the probability measure $P$, without any reference to $\Omega$ and $\mathcal{F}$.
#
# **Examples:**
# 1. Consider a single coin flip with a probability $p$ of coming up heads and define a probability space $\left(\Omega, \mathcal{F}, P\right)$ as before. Define a discrete real random variable $X$ by $X(H)=1$ and $X(T)=0$. Then $P\left(X=1\right)=p$ and $P\left(X=1\right)=1-p$.
# 2. Suppose you flip the coin above 10 times in a row. Let $\Omega$ denote the set of 10 letter words in the alphabet $\lbrace H, T\rbrace$, $\mathcal{F}=\mathcal{P}\left(\Omega\right)$, and let $P$ be determined by $P(H)=p$ and $P(T)=1-p$ in the obvious way. Suppose you are betting on the outcome of the coin flips: you win £1 for every head and lose £2 for every tail. Let $X$ be the discrete real random variable that represents you winnings at the end of the game. So, for example, $P(X=-20)=(1-p)^{10}$.

# %% [markdown]
# ## Stochastic Processes
#
# **Definition:** Let $\left(\Omega, \mathcal{F}, P\right)$ be a probability space, $\left(S, \Sigma\right)$ be a measurable space, and $T$ be a set. A *stochastic process* is a collection $\left(X_t\right)_{t\in T}$ of $\left(S, \Sigma\right)$-valued random variables. We call $S$ the *state space* and $T$ the *index set* or the *parameter set*.
#
# Often $T\subseteq\mathbb{R}$ and we think of $T$ as representing time. If $T\subseteq\mathbb{R}$ is discrete we call the stochastic process *discrete*. If $T\subseteq\mathbb{R}$ is an interval we call the process *continuous*.

# %% [markdown]
# ### Adapted Processes
#
# **Definition:** Suppose that $T$ is a totally ordered set, $\mathcal{F}$ is a set (or group, or $\sigma$-algebra, etc.), and $\left(\mathcal{F}_t\right)_{t\in T}$ is a collection of subsets (or subgroups, or sub-$\sigma$-algebras, etc.) of $\mathcal{F}$. We call $\left(\mathcal{F}_t\right)_{t\in T}$ a *filtration* of $\mathcal{F}$ if $\mathcal{F}_s\subseteq \mathcal{F}_t$ whenever $s\leq t$ for $s, t\in T$.
#
# **Definition:** Suppose that:
# - $\left(\Omega, \mathcal{F}, P\right)$ is a probability space;
# - $T$ is a totally ordered set;
# - $\left(\mathcal{F}_t\right)_{t\in T}$ is a filtration of the $\sigma$-algebra $\mathcal{F}$ (in particular, each $\mathcal{F}_t$ is itself a $\sigma$-algebra);
# - $\left(S, \Sigma\right)$ is a measurable space; and
# - $\left(X_t \right)_{t\in T}$ is a stochastic process.
#
# We say that the process $\left(X_t \right)_{t\in T}$ is *adapted to the filtration* $\left(\mathcal{F}_t\right)_{t\in T}$ if $X_t:\Omega\to S$ is $\left(\mathcal{F}_t, \Sigma\right)$-measurable for each $t\in T$; that is, if each $X_t$ is a random variable of the probability space $\left(\Omega, \mathcal{F}_t, P\big|_{\mathcal{F}_t}\right)$.
#
# We should think of $\mathcal{F}_t$ as the information available at time $t$.
#
# **Example:** Consider flipping a sequence of coins at integer time intervals (say every minute). Each coin has the same probability $p\in[0,1]$ of coming up heads.
#
# Let $T=\mathbb{Z}_{>0}$ and let $\Omega=\lbrace \text{H}, \text{T}\rbrace^T$; the set of sequences of $\text{H}$s and $\text{T}$s indexed by $T$. For $t\in T$, there is a natural embedding
#
# \begin{align}
#     \mathcal{P}\big( \lbrace \text{H}, \text{T}\rbrace^t\big) & \longrightarrow \mathcal{P}\left(\Omega\right) \\
#     S & \longmapsto \lbrace (\omega_i) \,|\, (\omega_1, \ldots, \omega_t)\in S\rbrace.
# \end{align}
#
# Let $\mathcal{F}_t\subseteq \mathcal{P}\left(\Omega\right)$ denote the image of this map and let Let $\mathcal{F} = \bigcup_{t\in T} \mathcal{F}_t$. Note that $\left(\mathcal{F}_t\right)_{t\in T}$ is a $\sigma$-algebra filtration of $\mathcal{F}$.
#
# Take $t\in T$. There is a unique probability measure $P_t:\mathcal{P}\big( \lbrace \text{H}, \text{T}\rbrace^t\big)\to[0, 1]$ that sends $\{\omega\}$ for $\omega\in\lbrace \text{H}, \text{T}\rbrace^t$ to $ p^s (1-p)^{t-s}$, where $s$ is the number of $\text{H}$s in $\omega$. Let $P:\mathcal{F}\to[0,1]$ be the unique probability measure that that agrees with the $P_t$ via the identification of $\mathcal{P}\big( \lbrace \text{H}, \text{T}\rbrace^t\big)$ with $\mathcal{F}_t$. The claim that this is well-defined reduces to the identity
#
# \begin{equation}
#     p^s (1-p)^{t-s} = p^{s+1} (1-p)^{t-s} + p^s (1-p)^{t+1-s}.
# \end{equation}
#
# Let $S=\mathbb{Z}$ and $\Sigma=\mathcal{P}\left( \mathbb{Z}\right)$. For $t\in T$, let $X_t$ be the discrete random variable $\Omega\to\mathbb{Z}$ that map a sequence $(\omega_s)$ to the number of $\text{H}$s in the truncated sequence $(\omega_1,\ldots, \omega_t)$.
#
# Then $(X_t)_{t\in T}$ is a stochastic process on $\left(\Omega, \mathcal{F}, P\right)$ and is adapted to the filtration $\left(\mathcal{F}_t\right)_{t\in T}$ of $\mathcal{F}$. Indeed, $X^{-1}(\{s\}$ is the image in $\mathcal{F}_t$ of the subset of $\lbrace \text{H}, \text{T}\rbrace^t$ consisting of sequences containing exactly $s$ $\text{H}$s.
#
# We can think of $X_t$ as counting the number of heads after $t$ coin flips and $\mathcal{F}_t$ as the information available at that time; that is, the outcomes that can be distinguished at time $t$. Note that this *only* works in the stochastic process framework: we couldn't assign a probability to an infinite sequence of $\text{H}$s and $\text{T}$s or count the heads, we have to break it down into observations at different times with the partial information available at that point.

# %% [markdown]
# ### Martingales
#
# **Definition:** A stochastic process is *stationary* if the variables $X_t$ are identically distributed.
#
# **Definition:** A martingale is a stochastic process for which, at a particular time, the conditional expectation of the next value in the sequence is equal to the present value.
#
# *What is the measure theoretic definition of conditional random variables and expectation?*

# %% [markdown]
# ## Glossary
#
# - Borel
#     - Sets
#     - $\sigma$-algebra
# - Event Space
# - Filtration
# - Martingale
# - Measurable
#     - Function
#     - Set
#     - Space
# - Probability
#     - Measure
#     - Space
# - Sample Space
# - Stochastic Process
#     - Adapted Stochastic Process
#     - Continuous Stochastic Process
#     - Discrete Stochastic Process
#     - Stationary Stochastic Process
# - State Space
# - Random Variable
#     - Discrete
#     - Real
#     - Real-Valued
# - $\sigma$-additive
# - $\sigma$-algebra
#     - Generated by a function
#     - Generated by a set
